# %%
import matplotlib.pyplot as plt
import random
import math

# %%
class agent2:
    def __init__(self):
        pass
    def game(self):
        pre_choose = random.randint(1,100)
        if pre_choose <=25:
            choose=1
        elif pre_choose<=38:
            choose=2
        elif pre_choose<=44:
            choose=3
        elif pre_choose<=50:
            choose=4
        else:
            choose =random.randint(5,100)
        return(choose)

# %%
class agent1:
    def __init__(self):
      pass
    def game(self):
        return(random.randint(1,100))
age=agent1()
print(age.game())
# Out:
# 92

# %%
agent_list=[]
count=0
for i in range(100):
    count+=1
    agent_list.append("age"+str(count))

# %%
won=[1]
class agent3:
    def __init__(self):
        pass
    def game(self):
        pre_choose = random.randint(1,100)
        if pre_choose <=25:
            choose=won[-1]
        elif pre_choose<=38:
            choose=won[-1]+1
        elif pre_choose<=44:
            choose=won[-1]+2
        elif pre_choose<=50:
            choose=won[-1]+3
        else:
            choose =random.randint(5,100)
        return(choose)

# %%
print(agent_list)
print(len(agent_list))
# Out:
# ['age1', 'age2', 'age3', 'age4', 'age5', 'age6', 'age7', 'age8', 'age9', 'age10', 'age11', 'age12', 'age13', 'age14', 'age15', 'age16', 'age17', 'age18', 'age19', 'age20', 'age21', 'age22', 'age23', 'age24', 'age25', 'age26', 'age27', 'age28', 'age29', 'age30', 'age31', 'age32', 'age33', 'age34', 'age35', 'age36', 'age37', 'age38', 'age39', 'age40', 'age41', 'age42', 'age43', 'age44', 'age45', 'age46', 'age47', 'age48', 'age49', 'age50', 'age51', 'age52', 'age53', 'age54', 'age55', 'age56', 'age57', 'age58', 'age59', 'age60', 'age61', 'age62', 'age63', 'age64', 'age65', 'age66', 'age67', 'age68', 'age69', 'age70', 'age71', 'age72', 'age73', 'age74', 'age75', 'age76', 'age77', 'age78', 'age79', 'age80', 'age81', 'age82', 'age83', 'age84', 'age85', 'age86', 'age87', 'age88', 'age89', 'age90', 'age91', 'age92', 'age93', 'age94', 'age95', 'age96', 'age97', 'age98', 'age99', 'age100']
# 100

# %%
num_list=list(range(1,101))
select_list=[]

# %%
class main_agent:
    def __init__(self):
        pass
    def game(self):
        num_list.append(won[-1])
        selected_num = random.choices(num_list, k=1)[0]
        choose=selected_num
        select_list.append(choose)
        return(choose)
age=main_agent()
print(age.game())
# Out:
# 6

# %%
#ゲーム実行
agent_list=[]
count=0
for i in range(100):
    count+=1
    agent_list.append("age"+str(count))
number_agent1=int(input())
number_agent2=int(input())
number_agent3=int(input())
total=number_agent1+number_agent2+number_agent3+1
print(number_agent1,number_agent2,number_agent3)
for i in range(number_agent1):
    agent_list[i+1]=agent1()
for i in range(number_agent2):
    agent_list[number_agent1+i+1]=agent2()
for i in range(number_agent3):
    agent_list[number_agent1+number_agent2+i+1]=agent3()
agent_list[0]=main_agent()
print(agent_list)
# Out:
# 33 33 33
at 0x0000019DA0F86570>, <__main__.agent2 object at 0x0000019DA0F865A0>, <__main__.agent2 object at 0x0000019DA0F865D0>, <__main__.agent2 object at 0x0000019DA0F86600>, <__main__.agent2 object at 0x0000019DA0F86630>, <__main__.agent2 object at 0x0000019DA0F86660>, <__main__.agent3 object at 0x0000019DA0F86690>, <__main__.agent3 object at 0x0000019DA0F866C0>, <__main__.agent3 object at 0x0000019DA0F866F0>, <__main__.agent3 object at 0x0000019DA0F86720>, <__main__.agent3 object at 0x0000019DA0F86750>, <__main__.agent3 object at 0x0000019DA0F86780>, <__main__.agent3 object at 0x0000019DA0F867B0>, <__main__.agent3 object at 0x0000019DA0F867E0>, <__main__.agent3 object at 0x0000019DA0F86810>, <__main__.agent3 object at 0x0000019DA0F86840>, <__main__.agent3 object at 0x0000019DA0F86870>, <__main__.agent3 object at 0x0000019DA0F868A0>, <__main__.agent3 object at 0x0000019DA0F868D0>, <__main__.agent3 object at 0x0000019DA0F86900>, <__main__.agent3 object at 0x0000019DA0F86930>, <__main__.agent3 object at 0x0000019DA0F86960>, <__main__.a ...

# %%
check_list=[20]
select_list=[]
for i in range(100):
    check_list.append(check_list[-1]+20)
won_number_list10=[]
for freq in check_list:
  times=freq
  won=[1]
  won_agent=[]
  won_dict={}
  num_list=list(range(1,101))
  won_agent_dict={"agent1":0,"agent2":0,"agent3":0,"main_agent":0}
  for q in range(100):
    won_dict[q+1]=0
  for reset_dict in range(times):
    game_dict={}
    agent_dict={}
    for game in range(total):
      a=agent_list[game].game()
      if a in game_dict:
          game_dict[a]+=1
      else:
          game_dict[a]=1
          if game==0:
             agent_dict[a]="main_agent"
          elif game+1<=number_agent1:
            agent_dict[a]="agent1"
          elif game+1<=number_agent1+number_agent2:
             agent_dict[a]="agent2"
          elif game+1<=total:
             agent_dict[a]="agent3"
    for check in range(total):
      if check in game_dict and game_dict[check]==1:
          won.append(check)
          won_agent_dict[agent_dict[check]]+=1
          won_dict[check]+=1
          break
  won=won[1:]
  won_number_list10.append(won_agent_dict["main_agent"]/times)

print(won_number_list10)
print(select_list)
# Out:
# [0.0, 0.0, 0.03333333333333333, 0.025, 0.05, 0.05, 0.06428571428571428, 0.0375, 0.05555555555555555, 0.04, 0.06363636363636363, 0.075, 0.05, 0.05, 0.04, 0.05, 0.06764705882352941, 0.06388888888888888, 0.042105263157894736, 0.045, 0.04285714285714286, 0.07272727272727272, 0.06086956521739131, 0.05625, 0.076, 0.04423076923076923, 0.06296296296296296, 0.05178571428571429, 0.056896551724137934, 0.06, 0.09193548387096774, 0.053125, 0.0696969696969697, 0.06470588235294118, 0.07285714285714286, 0.06666666666666667, 0.05810810810810811, 0.06578947368421052, 0.06538461538461539, 0.06875, 0.07073170731707316, 0.0761904761904762, 0.056976744186046514, 0.05568181818181818, 0.06222222222222222, 0.058695652173913045, 0.07127659574468086, 0.075, 0.07959183673469387, 0.074, 0.07352941176470588, 0.07211538461538461, 0.07452830188679
8, 7, 16, 8, 32, 4, 9, 61, 7, 14, 16, 44, 20, 6, 8, 92, 5, 8, 6, 5, 16, 53, 5, 8, 30, 46, 10, 18, 22, 7, 13, 6, 37, 17, 7, 48, 3, 7, 6, 11, 4, 6, 80, 3, 14, 60, 31, 7, 9, 35, 4, 5, 13, 12, 4, 22, 5, 71, 51, 70, 100, 1, 73, 97, 36, 74, 88, 91, 69, 15, 1, 3, 12, 15, 6, 51, 33, 27, 58, 23, 9, 13, 6, 6, 75, 92, 4, 8, 10, 5, 6, 49, 97, 54, 6, 93, 9, 5, 44, 79, 28, 10, 6, 93, 5, 6, 7, 70, 35, 91, 13, 6, 50, 7, 5, 53, 57, 88, 48, 14, 34, 54, 58, 99, 83, 6, 72, 74, 6, 72, 21, 9, 5, 90, 6, 16, 85, 12, 92, 5, 3, 5, 74, 74, 9, 97, 23, 7, 5, 8, 30, 22, 77, 95, 19, 45, 8, 13, 30, 71, 3, 5, 7, 3, 5, 19, 19, 7, 13, 11, 23, 49, 9, 95, 3, 9, 6, 78, 10, 6, 90, 3, 51, 10, 3, 8, 3, 5, 3, 10, 6, 92, 85, 42, 4, 3, 69, 68, 6, 6, 75, 3, 3, 42, 10, 4, 92, 9, 6, 5, 5, 72, 89, 8, 4, 2, 6, 9, 78, 19, 4, 7, 30, 11, 3, 36, 10, 40, 4, 94, 7, 10, 7, 55, 66, 7, 8, 9, 5, 2, 7, 7, 6, 8, 7, 9, 5, 3, 4, 10, 3, 4, 3, 1 ...

# %%
dictoo={}
listoo=[]
for i in select_list:
  if i not in dictoo:
    dictoo[i]=1
  else:
    dictoo[i]+=1
for i in range(100):
  listoo.append(dictoo[i+1])
plt.plot(list(range(1,101)),listoo)

# %%
for i in range(100):
  print(dictoo[i+1])
# Out:
# 525
# 3058
# 13478
# 9804
# 12193
# 8865
# 8417
# 6796
# 5851
# 4457
# 3088
# 2367
# 1708
# 1223
# 970
# 660
# 549
# 385
# 354
# 297
# 275
# 249
# 234
# 267
# 226
# 213
# 236
# 223
# 212
# 215
# 238
# 217
# 222
# 203
# 229
# 218
# 230
# 247
# 218
# 232
# 253
# 232
# 219
# 187
# 228
# 234
# 228
# 230
# 198
# 214
# 221
# 220
# 217
# 215
# 217
# 226
# 222
# 249
# 213
# 212
# 224
# 210
# 225
# 200
# 208
# 224
# 233
# 196
# 245
# 238
# 225
# 217
# 223
# 217
# 225
# 226
# 215
# 248
# 232
# 224
# 236
# 222
# 198
# 217
# 242
# 250
# 234
# 211
# 234
# 226
# 208
# 235
# 210
# 231
# 203
# 212
# 246
# 217
# 223
# 226

# %%
#反映率0.5
class main_agent:
    def __init__(self):
        pass
    def game(self):
        k=random.randint(1,2)
        if k==1:
          num_list.append(won[-1])
        selected_num = random.choices(num_list, k=1)[0]
        choose=selected_num
        return(choose)
age=main_agent()
print(age.game())
# Out:
# 3

# %%
check_list=[20]
for i in range(100):
    check_list.append(check_list[-1]+20)
won_number_list05=[]
for freq in check_list:
  times=freq
  won=[1]
  won_agent=[]
  won_dict={}
  num_list=list(range(1,101))
  won_agent_dict={"agent1":0,"agent2":0,"agent3":0,"main_agent":0}
  for q in range(100):
    won_dict[q+1]=0
  for reset_dict in range(times):
    game_dict={}
    agent_dict={}
    for game in range(total):
      a=agent_list[game].game()
      if a in game_dict:
          game_dict[a]+=1
      else:
          game_dict[a]=1
          if game==0:
             agent_dict[a]="main_agent"
          elif game+1<=number_agent1:
            agent_dict[a]="agent1"
          elif game+1<=number_agent1+number_agent2:
             agent_dict[a]="agent2"
          elif game+1<=total:
             agent_dict[a]="agent3"
    for check in range(total):
      if check in game_dict and game_dict[check]==1:
          won.append(check)
          won_agent_dict[agent_dict[check]]+=1
          won_dict[check]+=1
          break
  won=won[1:]
  won_number_list05.append(won_agent_dict["main_agent"]/times)

print(won_number_list05)
# Out:
# [0.0, 0.025, 0.016666666666666666, 0.025, 0.01, 0.025, 0.05714285714285714, 0.01875, 0.05, 0.06, 0.01818181818181818, 0.0625, 0.06538461538461539, 0.05714285714285714, 0.03333333333333333, 0.059375, 0.052941176470588235, 0.041666666666666664, 0.04736842105263158, 0.055, 0.05476190476190476, 0.05454545454545454, 0.07391304347826087, 0.058333333333333334, 0.068, 0.05576923076923077, 0.05185185185185185, 0.06785714285714285, 0.05344827586206897, 0.04666666666666667, 0.06290322580645161, 0.078125, 0.0696969696969697, 0.0661764705882353, 0.07, 0.07916666666666666, 0.05675675675675676, 0.07368421052631578, 0.07692307692307693, 0.06375, 0.06463414634146342, 0.05476190476190476, 0.06511627906976744, 0.06363636363636363, 0.06777777777777778, 0.06739130434782609, 0.06808510638297872, 0.06666666666666667, 0.06224489795918367, 0.07, 0.06568627450980392, 0.08365384615384615, 0.052830188679245285, 0.07592592592592592, 0.06181818181818182, 0.06428571428571428, 0.07280701754385965, 0.06810344827586207, 0.07542372881355933, 0.07833333333333334, 0.07213114754098361, 0.075, 0.0626984126984127, 0.06875, 0.06615384615384616, 0.06893939393939394, 0.07388059701492537, 0.07205882352941176, 0.06666666666666667, 0.07642857142857143, 0.06901408450704226, 0.07430555555555556, 0.07808219178082192, 0.06554054054054054, 0.06333333333333334, 0.08947368421052632, 0.06753246753246753, 0.06025641025641026, 0.0759493670886076, 0.085625, 0.07654320987654321, 0.0701219512195122, 0.06204819277108434, 0.06785714285714285, 0.08470588235294117, 0.07209302325581396, 0.07988505747126437, 0.06818181818181818, 0.0702247191011236, 0.07055555555555555, 0.06758241758241758, 0.07010869565217391, 0.08118279569892473, 0.08031914893617022, 0.07631578947368421, 0.08229166666666667, 0.08041237113402062, 0.07908163265306123, 0.07222222222222222, 0.0795, 0.08118811881188119]

# %%
#反映率0.25
class main_agent:
    def __init__(self):
        pass
    def game(self):
        k=random.randint(1,4)
        if k==1:
          num_list.append(won[-1])
        selected_num = random.choices(num_list, k=1)[0]
        choose=selected_num
        return(choose)
age=main_agent()
print(age.game())
# Out:
# 5

# %%
check_list=[20]
for i in range(100):
    check_list.append(check_list[-1]+20)
won_number_list025=[]
for freq in check_list:
  times=freq
  won=[1]
  won_agent=[]
  won_dict={}
  num_list=list(range(1,101))
  won_agent_dict={"agent1":0,"agent2":0,"agent3":0,"main_agent":0}
  for q in range(100):
    won_dict[q+1]=0
  for reset_dict in range(times):
    game_dict={}
    agent_dict={}
    for game in range(total):
      a=agent_list[game].game()
      if a in game_dict:
          game_dict[a]+=1
      else:
          game_dict[a]=1
          if game==0:
             agent_dict[a]="main_agent"
          elif game+1<=number_agent1:
            agent_dict[a]="agent1"
          elif game+1<=number_agent1+number_agent2:
             agent_dict[a]="agent2"
          elif game+1<=total:
             agent_dict[a]="agent3"
    for check in range(total):
      if check in game_dict and game_dict[check]==1:
          won.append(check)
          won_agent_dict[agent_dict[check]]+=1
          won_dict[check]+=1
          break
  won=won[1:]
  won_number_list025.append(won_agent_dict["main_agent"]/times)

print(won_number_list025)
# Out:
# [0.05, 0.025, 0.03333333333333333, 0.025, 0.05, 0.016666666666666666, 0.02857142857142857, 0.01875, 0.05555555555555555, 0.035, 0.045454545454545456, 0.029166666666666667, 0.046153846153846156, 0.04642857142857143, 0.04666666666666667, 0.04375, 0.061764705882352944, 0.044444444444444446, 0.05263157894736842, 0.055, 0.06428571428571428, 0.07045454545454545, 0.05217391304347826, 0.06041666666666667, 0.058, 0.07115384615384615, 0.08703703703703704, 0.05357142857142857, 0.05, 0.04666666666666667, 0.06451612903225806, 0.0828125, 0.07121212121212121, 0.07647058823529412, 0.06142857142857143, 0.05416666666666667, 0.052702702702702706, 0.07105263157894737, 0.08333333333333333, 0.0875, 0.06585365853658537, 0.06547619047619048, 0.06395348837209303, 0.060227272727272727, 0.07333333333333333, 0.08369565217391305, 0.0627659574468085, 0.059375, 0.07040816326530612, 0.074, 0.06862745098039216, 0.08653846153846154, 0.07169811320754717, 0.07314814814814814, 0.07454545454545454, 0.060714285714285714, 0.0780701754385965, 0.07844827586206897, 0.0847457627118644, 0.06333333333333334, 0.06967213114754098, 0.062096774193548386, 0.0626984126984127, 0.05703125, 0.06923076923076923, 0.07954545454545454, 0.07835820895522388, 0.06102941176470588, 0.06666666666666667, 0.09142857142857143, 0.05985915492957746, 0.08402777777777778, 0.08150684931506849, 0.06756756756756757, 0.078, 0.07236842105263158, 0.07272727272727272, 0.06602564102564103, 0.07974683544303797, 0.075625, 0.06358024691358025, 0.061585365853658536, 0.06385542168674699, 0.07202380952380952, 0.07352941176470588, 0.08255813953488372, 0.07011494252873564, 0.06875, 0.0696629213483146, 0.06888888888888889, 0.07637362637362638, 0.08641304347826087, 0.07634408602150537, 0.08776595744680851, 0.07210526315789474, 0.06927083333333334, 0.07474226804123711, 0.07959183673469387, 0.08383838383838384, 0.065, 0.07623762376237624]

# %%
plt.plot(check_list,won_number_list10,color="red")
plt.plot(check_list,won_number_list05,color="blue")
plt.plot(check_list,won_number_list025,color="green")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
