# %%
import matplotlib.pyplot as plt
import random
import math

# %%
class agent2:
    def __init__(self):
        pass
    def game(self):
        pre_choose = random.randint(1,100)
        if pre_choose <=25:
            choose=1
        elif pre_choose<=38:
            choose=2
        elif pre_choose<=44:
            choose=3
        elif pre_choose<=50:
            choose=4
        else:
            choose =random.randint(5,100)
        return(choose)

# %%
class agent1:
    def __init__(self):
      pass
    def game(self):
        return(random.randint(1,100))
age=agent1()
print(age.game())
# Out:
# 63

# %%
agent_list=[]
count=0
for i in range(100):
    count+=1
    agent_list.append("age"+str(count))

# %%
won=[1]
class agent3:
    def __init__(self):
        pass
    def game(self):
        pre_choose = random.randint(1,100)
        if pre_choose <=25:
            choose=won[-1]
        elif pre_choose<=38:
            choose=won[-1]+1
        elif pre_choose<=44:
            choose=won[-1]+2
        elif pre_choose<=50:
            choose=won[-1]+3
        else:
            choose =random.randint(5,100)
        return(choose)

# %%
print(agent_list)
print(len(agent_list))
# Out:
# ['age1', 'age2', 'age3', 'age4', 'age5', 'age6', 'age7', 'age8', 'age9', 'age10', 'age11', 'age12', 'age13', 'age14', 'age15', 'age16', 'age17', 'age18', 'age19', 'age20', 'age21', 'age22', 'age23', 'age24', 'age25', 'age26', 'age27', 'age28', 'age29', 'age30', 'age31', 'age32', 'age33', 'age34', 'age35', 'age36', 'age37', 'age38', 'age39', 'age40', 'age41', 'age42', 'age43', 'age44', 'age45', 'age46', 'age47', 'age48', 'age49', 'age50', 'age51', 'age52', 'age53', 'age54', 'age55', 'age56', 'age57', 'age58', 'age59', 'age60', 'age61', 'age62', 'age63', 'age64', 'age65', 'age66', 'age67', 'age68', 'age69', 'age70', 'age71', 'age72', 'age73', 'age74', 'age75', 'age76', 'age77', 'age78', 'age79', 'age80', 'age81', 'age82', 'age83', 'age84', 'age85', 'age86', 'age87', 'age88', 'age89', 'age90', 'age91', 'age92', 'age93', 'age94', 'age95', 'age96', 'age97', 'age98', 'age99', 'age100']
# 100

# %%
num_list=list(range(1,101))

# %%
class main_agent:
    def __init__(self):
        pass
    def game(self):
        num_list.append(won[-1])
        selected_num = random.choices(num_list, k=1)[0]
        choose=selected_num
        return(choose)
age=main_agent()
print(age.game())
# Out:
# 3

# %%
#ゲーム実行
agent_list=[]
count=0
for i in range(100):
    count+=1
    agent_list.append("age"+str(count))
number_agent1=int(input())
number_agent2=int(input())
number_agent3=int(input())
total=number_agent1+number_agent2+number_agent3+1
print(number_agent1,number_agent2,number_agent3)
for i in range(number_agent1):
    agent_list[i+1]=agent1()
for i in range(number_agent2):
    agent_list[number_agent1+i+1]=agent2()
for i in range(number_agent3):
    agent_list[number_agent1+number_agent2+i+1]=agent3()
agent_list[0]=main_agent()
print(agent_list)
# Out:
# 33 33 33
# [<__main__.main_agent object at 0x0000029DF1B9EFC0>, <__main__.agent1 object at 0x0000029DF1BE8E00>, <__main__.agent1 object at 0x0000029DF432EA50>, <__main__.agent1 object at 0x0000029DF1B9ED80>, <__main__.agent1 object at 0x0000029DF1A68CE0>, <__main__.agent1 object at 0x0000029DF1A69190>, <__main__.agent1 object at 0x0000029DF1A691C0>, <__main__.agent1 object at 0x0000029DF1A691F0>, <__main__.agent1 object at 0x0000029DF1A69370>, <__main__.agent1 object at 0x0000029DF1A692E0>, <__main__.agent1 object at 0x0000029DF1A69310>, <__main__.agent1 object at 0x0000029DF1A68A40>, <__main__.agent1 object at 0x0000029DF1A69220>, <__main__.agent1 object at 0x0000029DF1A68F50>, <__main__.agent1 object at 0x0000029DF1A694C0>, <__main__.agent1 object at 0x0000029DF1A69520>, <__main__.agent1 object at 0x0000029DF1A69280>, <__main__.agent1 object at 0x0000029DF1A69580>, <__main__.agent1 object at 0x0000029DF1A694F0>, <__main__.agent1 object at 0x0000029DF1A68FE0>, <__main__.agent1 object at 0x0000029DF1A69460>, <__main__.agent1 object at 0x0000029DF1A6B260>, <__main__.agent1 object at 0x0000029DF1A69610>, <__main__.agent1 object at 0x0000029DF1A6B410>, <__main__.agent1 object at 0x0000029DF1A69640>, <__main__.agent1 object at 0x0000029DF1A69670>, <__main__.agent1 object at 0x0000029DF1A696A0>, <__main__.agent1 object at 0x0000029DF1A696D0>, <__main__.agent1 object at 0x0000029DF1A69700>, <__main__.agent1 object at 0x0000029DF1A69730>, <__main__.agent1 object at 0x0000029DF1A69760>, <__main__.agent1 object at 0x0000029DF1A69790>, <__main__.agent1 object at 0x0000029DF1A697C0>, <__main__.agent1 object at 0x0000029DF1A697F0>, <__main__.agent2 object at 0x0000029DF1A69820>, <__main__.agent2 object at 0x0000029DF1BE5D30>, <__main__.agent2 object at 0x0000029DF1A69880>, <__main__.agent2 object at 0x0000029DF1A698B0>, <__main__.agent2 object at 0x0000029DF1A698E0>, <__main__.agent2 object at 0x0000029DF1A69910>, <__main__.agent2 object at 0x0000029DF1A69940>, <__main__.agent2 object at 0x0000029DF1A69970>, <__main__.agent2 object at 0x0000029DF1A699A0>, <__main__.agent2 object at 0x0000029DF1A699D0>, <__main__.agent2 object at 0x0000029DF1A69A00>, <__main__.agent2 object at 0x0000029DF1A69A30>, <__main__.agent2 object at 0x0000029DF1A69A60>, <__main__.agent2 object at 0x0000029DF1A69A90>, <__main__.agent2 object at 0x0000029DF1A69AC0>, <__main__.agent2 object at 0x0000029DF1A69AF0>, <__main__.agent2 object at 0x0000029DF1A69B20>, <__main__.agent2 object at 0x0000029DF1A69B50>, <__main__.agent2 object at 0x0000029DF1A69B80>, <__main__.agent2 object at 0x0000029DF1A69BB0>, <__main__.agent2 object at 0x0000029DF1A69BE0>, <__main__.agent2 object at 0x0000029DF1A69C10>, <__main__.agent2 object at 0x0000029DF1A69C40>, <__main__.agent2 object at 0x0000029DF1A6B560>, <__main__.agent2 object at 0x0000029DF1A69C70>, <__main__.agent2 object at 0x0000029DF1A6B4D0>, <__main__.agent2 object at 0x0000029DF1A69CA0>, <__main__.agent2 object at 0x0000029DF1A69CD0>, <__main__.agent2 object at 0x0000029DF1A69D00>, <__main__.agent2 object at 0x0000029DF1A69D30>, <__main__.agent2 object at 0x0000029DF1A69D60>, <__main__.agent2 object at 0x0000029DF1A69D90>, <__main__.agent2 object at 0x0000029DF1A69DC0>, <__main__.agent3 object at 0x0000029DF1A69DF0>, <__main__.agent3 object at 0x0000029DF1A69E20>, <__main__.agent3 object at 0x0000029DF1A69E50>, <__main__.agent3 object at 0x0000029DF1A69E80>, <__main__.agent3 object at 0x0000029DF1A69EB0>, <__main__.agent3 object at 0x0000029DF1A69EE0>, <__main__.agent3 object at 0x0000029DF1A69F10>, <__main__.agent3 object at 0x0000029DF1A69F40>, <__main__.agent3 object at 0x0000029DF1A69FA0>, <__main__.agent3 object at 0x0000029DF1A69FD0>, <__main__.agent3 object at 0x0000029DF1A6A000>, <__main__.agent3 object at 0x0000029DF1A6A030>, <__main__.agent3 object at 0x0000029DF1A6A060>, <__main__.agent3 object at 0x0000029DF1A6A090>, <__main__.agent3 object at 0x0000029DF1A6A0C0>, <__main__.agent3 object at 0x0000029DF1A6A0F0>, <__main__.a ...

# %%
check_list=[20]
for i in range(100):
    check_list.append(check_list[-1]+20)
won_number_list10=[]
for freq in check_list:
  times=freq
  won=[1]
  won_agent=[]
  won_dict={}
  num_list=list(range(1,101))
  won_agent_dict={"agent1":0,"agent2":0,"agent3":0,"main_agent":0}
  for q in range(100):
    won_dict[q+1]=0
  for reset_dict in range(times):
    game_dict={}
    agent_dict={}
    for game in range(total):
      a=agent_list[game].game()
      if a in game_dict:
          game_dict[a]+=1
      else:
          game_dict[a]=1
          if game==0:
             agent_dict[a]="main_agent"
          elif game+1<=number_agent1:
            agent_dict[a]="agent1"
          elif game+1<=number_agent1+number_agent2:
             agent_dict[a]="agent2"
          elif game+1<=total:
             agent_dict[a]="agent3"
    for check in range(total):
      if check in game_dict and game_dict[check]==1:
          won.append(check)
          won_agent_dict[agent_dict[check]]+=1
          won_dict[check]+=1
          break
  won=won[1:]
  won_number_list10.append(won_agent_dict["main_agent"]/times)

print(won_number_list10)
# Out:
# [0.0, 0.0, 0.06666666666666667, 0.0375, 0.05, 0.025, 0.02142857142857143, 0.05, 0.044444444444444446, 0.035, 0.05, 0.058333333333333334, 0.06153846153846154, 0.05357142857142857, 0.05, 0.059375, 0.05588235294117647, 0.04722222222222222, 0.06578947368421052, 0.06, 0.06428571428571428, 0.05909090909090909, 0.0782608695652174, 0.04583333333333333, 0.066, 0.05961538461538462, 0.06296296296296296, 0.05892857142857143, 0.05344827586206897, 0.056666666666666664, 0.054838709677419356, 0.0703125, 0.07575757575757576, 0.06323529411764706, 0.04428571428571428, 0.06527777777777778, 0.05810810810810811, 0.07368421052631578, 0.06666666666666667, 0.07, 0.06219512195121951, 0.07380952380952381, 0.07441860465116279, 0.0715909090909091, 0.056666666666666664, 0.07717391304347826, 0.06382978723404255, 0.06145833333333333, 0.06020408163265306, 0.07, 0.06764705882352941, 0.08076923076923077, 0.07075471698113207, 0.05740740740740741, 0.06363636363636363, 0.07946428571428571, 0.07456140350877193, 0.07586206896551724, 0.0576271186440678, 0.07, 0.07868852459016394, 0.06290322580645161, 0.05476190476190476, 0.07421875, 0.07384615384615385, 0.07424242424242425, 0.0880597014925373, 0.058823529411764705, 0.06666666666666667, 0.07214285714285715, 0.06901408450704226, 0.0763888888888889, 0.07123287671232877, 0.08175675675675675, 0.076, 0.08026315789473684, 0.08246753246753247, 0.06794871794871794, 0.06392405063291139, 0.081875, 0.07098765432098765, 0.08231707317073171, 0.06385542168674699, 0.075, 0.08, 0.07965116279069767, 0.08103448275862069, 0.08238636363636363, 0.0651685393258427, 0.08222222222222222, 0.06813186813186813, 0.07608695652173914, 0.06129032258064516, 0.06914893617021277, 0.07210526315789474, 0.06614583333333333, 0.07628865979381444, 0.06938775510204082, 0.07626262626262627, 0.077, 0.07623762376237624]

# %%
#反映率0.5
class main_agent:
    def __init__(self):
        pass
    def game(self):
        k=random.randint(1,2)
        if k==1:
          num_list.append(won[-1])
        selected_num = random.choices(num_list, k=1)[0]
        choose=selected_num
        return(choose)
age=main_agent()
print(age.game())
# Out:
# 5

# %%
check_list=[20]
for i in range(100):
    check_list.append(check_list[-1]+20)
won_number_list05=[]
for freq in check_list:
  times=freq
  won=[1]
  won_agent=[]
  won_dict={}
  num_list=list(range(1,101))
  won_agent_dict={"agent1":0,"agent2":0,"agent3":0,"main_agent":0}
  for q in range(100):
    won_dict[q+1]=0
  for reset_dict in range(times):
    game_dict={}
    agent_dict={}
    for game in range(total):
      a=agent_list[game].game()
      if a in game_dict:
          game_dict[a]+=1
      else:
          game_dict[a]=1
          if game==0:
             agent_dict[a]="main_agent"
          elif game+1<=number_agent1:
            agent_dict[a]="agent1"
          elif game+1<=number_agent1+number_agent2:
             agent_dict[a]="agent2"
          elif game+1<=total:
             agent_dict[a]="agent3"
    for check in range(total):
      if check in game_dict and game_dict[check]==1:
          won.append(check)
          won_agent_dict[agent_dict[check]]+=1
          won_dict[check]+=1
          break
  won=won[1:]
  won_number_list05.append(won_agent_dict["main_agent"]/times)

print(won_number_list05)
# Out:
# [0.0, 0.0, 0.016666666666666666, 0.0375, 0.04, 0.03333333333333333, 0.02142857142857143, 0.01875, 0.06111111111111111, 0.04, 0.04090909090909091, 0.058333333333333334, 0.07692307692307693, 0.039285714285714285, 0.05, 0.025, 0.06764705882352941, 0.06388888888888888, 0.042105263157894736, 0.065, 0.04523809523809524, 0.045454545454545456, 0.058695652173913045, 0.052083333333333336, 0.064, 0.0673076923076923, 0.05925925925925926, 0.06964285714285715, 0.05344827586206897, 0.05333333333333334, 0.06612903225806452, 0.09375, 0.07272727272727272, 0.058823529411764705, 0.05285714285714286, 0.06527777777777778, 0.05540540540540541, 0.05526315789473684, 0.06538461538461539, 0.05625, 0.07317073170731707, 0.055952380952380955, 0.07441860465116279, 0.06818181818181818, 0.06333333333333334, 0.06304347826086956, 0.06808510638297872, 0.06875, 0.06326530612244897, 0.069, 0.06274509803921569, 0.0673076923076923, 0.06132075471698113, 0.06574074074074074, 0.06818181818181818, 0.060714285714285714, 0.08596491228070176, 0.05862068965517241, 0.07542372881355933, 0.08083333333333333, 0.07459016393442623, 0.07096774193548387, 0.06825396825396825, 0.07421875, 0.07615384615384616, 0.08181818181818182, 0.05970149253731343, 0.058823529411764705, 0.0746376811594203, 0.06785714285714285, 0.06619718309859154, 0.09513888888888888, 0.07123287671232877, 0.07364864864864865, 0.07733333333333334, 0.07894736842105263, 0.07792207792207792, 0.07756410256410257, 0.0620253164556962, 0.06625, 0.08456790123456791, 0.06707317073170732, 0.07168674698795181, 0.075, 0.07176470588235294, 0.08197674418604652, 0.07586206896551724, 0.07954545454545454, 0.07696629213483146, 0.07, 0.06868131868131869, 0.07065217391304347, 0.07419354838709677, 0.07180851063829788, 0.07789473684210527, 0.06614583333333333, 0.07680412371134021, 0.07040816326530612, 0.08636363636363636, 0.071, 0.07128712871287128]

# %%
#反映率0.25
class main_agent:
    def __init__(self):
        pass
    def game(self):
        k=random.randint(1,4)
        if k==1:
          num_list.append(won[-1])
        selected_num = random.choices(num_list, k=1)[0]
        choose=selected_num
        return(choose)
age=main_agent()
print(age.game())
# Out:
# 4

# %%
check_list=[20]
for i in range(100):
    check_list.append(check_list[-1]+20)
won_number_list025=[]
for freq in check_list:
  times=freq
  won=[1]
  won_agent=[]
  won_dict={}
  num_list=list(range(1,101))
  won_agent_dict={"agent1":0,"agent2":0,"agent3":0,"main_agent":0}
  for q in range(100):
    won_dict[q+1]=0
  for reset_dict in range(times):
    game_dict={}
    agent_dict={}
    for game in range(total):
      a=agent_list[game].game()
      if a in game_dict:
          game_dict[a]+=1
      else:
          game_dict[a]=1
          if game==0:
             agent_dict[a]="main_agent"
          elif game+1<=number_agent1:
            agent_dict[a]="agent1"
          elif game+1<=number_agent1+number_agent2:
             agent_dict[a]="agent2"
          elif game+1<=total:
             agent_dict[a]="agent3"
    for check in range(total):
      if check in game_dict and game_dict[check]==1:
          won.append(check)
          won_agent_dict[agent_dict[check]]+=1
          won_dict[check]+=1
          break
  won=won[1:]
  won_number_list025.append(won_agent_dict["main_agent"]/times)

print(won_number_list025)
# Out:
# [0.0, 0.025, 0.016666666666666666, 0.0375, 0.03, 0.016666666666666666, 0.04285714285714286, 0.03125, 0.022222222222222223, 0.035, 0.03636363636363636, 0.0375, 0.023076923076923078, 0.039285714285714285, 0.04666666666666667, 0.040625, 0.03823529411764706, 0.05555555555555555, 0.07631578947368421, 0.0625, 0.05238095238095238, 0.05909090909090909, 0.043478260869565216, 0.04583333333333333, 0.074, 0.06346153846153846, 0.07222222222222222, 0.0625, 0.06724137931034482, 0.06333333333333334, 0.06451612903225806, 0.0703125, 0.05757575757575758, 0.06323529411764706, 0.06142857142857143, 0.05, 0.05810810810810811, 0.06447368421052632, 0.06666666666666667, 0.0725, 0.05731707317073171, 0.06428571428571428, 0.08023255813953488, 0.05795454545454545, 0.08888888888888889, 0.06630434782608696, 0.0797872340425532, 0.06145833333333333, 0.07755102040816327, 0.065, 0.07058823529411765, 0.06634615384615385, 0.07169811320754717, 0.06759259259259259, 0.08727272727272728, 0.060714285714285714, 0.07368421052631578, 0.07586206896551724, 0.06949152542372881, 0.0775, 0.07295081967213114, 0.05887096774193548, 0.06984126984126984, 0.06484375, 0.06923076923076923, 0.06818181818181818, 0.07537313432835821, 0.07279411764705883, 0.07101449275362319, 0.07714285714285714, 0.06338028169014084, 0.08055555555555556, 0.06643835616438357, 0.07432432432432433, 0.06533333333333333, 0.07763157894736843, 0.06363636363636363, 0.08269230769230769, 0.07025316455696203, 0.07625, 0.06728395061728396, 0.06951219512195123, 0.06927710843373494, 0.07380952380952381, 0.07294117647058823, 0.07325581395348837, 0.07011494252873564, 0.06306818181818181, 0.08707865168539326, 0.07111111111111111, 0.07747252747252747, 0.08097826086956522, 0.06989247311827956, 0.07021276595744681, 0.08, 0.0703125, 0.07525773195876288, 0.06326530612244897, 0.06818181818181818, 0.078, 0.08514851485148515]

# %%
plt.plot(check_list,won_number_list10,)
plt.plot(check_list,won_number_list05)
plt.plot(check_list,won_number_list025)
